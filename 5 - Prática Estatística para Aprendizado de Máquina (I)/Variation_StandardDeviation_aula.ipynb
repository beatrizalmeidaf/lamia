# %% [markdown]
# ## Variância e Desvio Padrão

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(100)
incomes = np.random.normal(100.0, 20.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std(), incomes.var()
# Out:
# (20.125927092006116, 405.05294131274576)

# %%
incomes = np.random.normal(100.0, 10.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes = np.random.normal(100.0, 150.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std(), incomes.var()
# Out:
# (149.28886578199854, 22287.16544647557)

# %%
incomes = np.random.normal(100.0, 2.0, 2000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std(), incomes.var()
# Out:
# (2.016022037760682, 4.064344856736733)
