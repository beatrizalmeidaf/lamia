# %% [markdown]
# ## Percentis

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(170)
vals = np.random.normal(0, 0.6, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 99)
# Out:
# 1.3444906492578486

# %%
np.percentile(vals, 50)
# Out:
# -0.010711606989163208

# %%
np.random.seed(150)
vals = np.random.normal(0, 8, 1000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# -0.14113342779808874

# %%
np.percentile(vals, 90)
# Out:
# 10.402527567723313

# %% [markdown]
# ## Momentos

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(10)
vals = np.random.normal(0, 0.9, 10000)

plt.hist(vals, 70)
plt.show()

# %%
# Momento de primeira ordem
np.mean(vals)
# Out:
# 0.0045918504017234425

# %%
# Momento de segunda ordem
np.var(vals)
# Out:
# 0.7933422351220526

# %%
# Momento de terceira ordem
import scipy.stats as sp
sp.skew(vals)
# Indica que possui uma cauda mais acentuada a esquerda
# Out:
# -0.028247129262426902

# %%
# Momento de quarta ordem
sp.kurtosis(vals)
# Out:
# 0.0001753996447910744

# %%
np.random.seed(10)
vals = np.random.normal(10, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
sp.skew(vals)
# Out:
# -0.02824712926243256
